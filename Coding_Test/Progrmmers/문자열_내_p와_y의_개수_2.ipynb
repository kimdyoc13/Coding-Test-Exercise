# %%
def solution(s):
    
    
    s = s.upper
    count_s = 0
    count_p = 0
    
    for i in s:
        if i == S:
            count_s += 1
        elif i == P:
            count_p += 1
    
    if count_s == count_p:
        answer = true
    else:
        answer = false
    
    
    

    return answer

# %%
def solution(s):
    
    
    s = s.upper
    count_s = 0
    count_p = 0
    
    for i in s:
        if i == 'S':
            count_s += 1
        elif i == 'P':
            count_p += 1
    
    if count_s == count_p:
        answer = 'true'
    else:
        answer = 'false'
    
    
    

    return answer

# %%
def solution(s):
    
    
    s = s.upper()
    count_s = 0
    count_p = 0
    
    for i in s:
        if i == 'S':
            count_s += 1
        elif i == 'P':
            count_p += 1
    
    if count_s == count_p:
        answer = 'true'
    else:
        answer = 'false'
    
    
    

    return answer

# %%
def solution(s):
    
    
    s = s.upper()
    count_s = 0
    count_p = 0
    
    for i in s:
        if i == 'S':
            count_s += 1
        elif i == 'P':
            count_p += 1
    
    if count_s == count_p:
        answer = true
    else:
        answer = false
    
    
    

    return answer

# %%
def solution(s):
    
    
    s = s.upper()
    count_s = 0
    count_p = 0
    
    for i in s:
        if i == S:
            count_s += 1
        elif i == P:
            count_p += 1
    
    if count_s == count_p:
        answer = true
    else:
        answer = false
    
    
    

    return answer

# %%
def solution(s):
    
    
    s = s.upper()
    count_s = 0
    count_p = 0
    
    for i in s:
        if i == 'S':
            count_s += 1
        elif i == 'P':
            count_p += 1
    
    if count_s == count_p:
        answer = true
    else:
        answer = false
    
    
    

    return answer

# %%
def solution(s):
    
    
    s = s.upper()
    count_s = 0
    count_p = 0
    
    for i in s:
        if i == 'S':
            count_s += 1
        elif i == 'P':
            count_p += 1
    
    if count_s == count_p:
        answer = true
    else:
        answer = false
    
    
    return answer

# %%
def solution(s):
    
    
    s = s.upper()
    count_s = 0
    count_p = 0
    
    for i in s:
        if i == 'S':
            count_s += 1
        elif i == 'P':
            count_p += 1
    
    if count_s == count_p:
        return true
    else:
        return false

# %%
def solution(s):
    
    
    s = s.upper()
    count_s = 0
    count_p = 0
    
    for i in s:
        if i == 'S':
            count_s += 1
        elif i == 'P':
            count_p += 1
    
    if count_s == count_p:
        answer = 'true'
    else:
        answer = 'false'
    
    
return answer

# %%
def solution(s):
    
    
    s = s.upper()
    count_s = 0
    count_p = 0
    
    for i in s:
        if i == 'S':
            count_s += 1
        elif i == 'P':
            count_p += 1
    
    if count_s == count_p:
        answer = True
    else:
        answer = False
    
    return answer

# %%
def solution(s):
    
    
    s = s.upper()
    count_s = 0
    count_p = 0
    
    for i in s:
        if i == 'S':
            count_s += 1
        elif i == 'P':
            count_p += 1
    
    if count_s == count_p:
        answer = True
    elif count_s != count_p:
        answer = False
    
    return answer

# %%
def solution(s):
    
    
    s = s.upper()
    count_y = 0
    count_p = 0
    
    for i in s:
        if i == 'Y':
            count_y += 1
        elif i == 'P':
            count_p += 1
    
    if count_y == count_p:
        answer = True
    elif count_y != count_p:
        answer = False
    
    return answer

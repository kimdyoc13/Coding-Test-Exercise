# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # . 루프를 활용한 솔루션

# %%
def solution(phone_book):
    # 1. 비교할 A 선택

    answer = True
    return answer

print(solution(["6", "12", "6789"]))
